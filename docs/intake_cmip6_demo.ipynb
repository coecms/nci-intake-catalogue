# %%
# Load intake module and the `nci` catalogue
import intake
cat = intake.cat.nci
list(cat)
# Out:
# ['era5', 'era5_land', 'ecmwf', 'esgf', 'cosima', 'erai']

# %%
# CMIP6 is included in `esgf` which is itself a catalogue
# so we are using list() again to see the sub-catalogues
esgf = cat['esgf']
list(esgf)
# Out:
# ['cmip5',
#  'cmip5_all',
#  'cmip5_gr1p5',
#  'cmip6',
#  'cmip6_all',
#  'cmip6_gr1p5',
#  'cordex',
#  'cordex_all']

# %%
# NB you can also use esgf._entries to see a much more detailed description of `esgf` entries
esgf._entries
# Out:
# {'cmip5': name: cmip5
#  container: xarray
#  plugin: ['esm_datastore']
#  driver: ['esm_datastore']
#  description: CMIP5 (Latest Versions)
#
#  Datasets on Gadi, both publised and replicated. Only the latest available file versions are in the listing, see catalogue 'cmip5_all' for all available versions
#
#  Catalogue columns match those used by ESGF search (esgf.nci.org.au). intake-esm dict keys are in the form '{esgf instance_id}.{variable}'. Columns 'model_id' and 'institution_id' mirror the non-'_id' columns, with minor formatting differences needed to create the 'instance_id'.
#
#  Project: al33, rr3
#  Maintained By: NCI
#  Contact: help@nci.org.au
#  References:
#      - https://pcmdi.llnl.gov/mips/cmip5/
#
#  direct_access: forbid
#  user_parameters: []
#  metadata:
#  args:
#    esmcol_obj: {{CATALOG_DIR}}/cmip5/catalogue_latest.json,
#  'cmip5_all': name: cmip5_all
#  container: xarray
#  plugin: ['esm_datastore']
#  driver: ['esm_datastore']
#  description: CMIP5 (All Versions)
#
#  Datasets on Gadi, both publised and replicated. All file versions present are in the listing, see catalogue 'cmip5' for only the latest versions
#
#  Catalogue columns match those used by ESGF search (esgf.nci.org.au). intake-esm dict keys are in the form '{esgf instance_id}.{variable}'. Columns 'model_id' and 'institution_id' mirror the non-'_id' columns, with minor formatting differences needed to create the 'instance_id'.
#
#  Project: al33, rr3
#  Maintained By: NCI
#  Contact: help@nci.org.au
#  References:
#      - https://pcmdi.llnl.gov/mips/cmip5/
#
#  direct_access: forbid
#  user_parameters: []
#  metadata:
#  args:
#    esmcol_obj: {{CATALOG_DIR}}/cmip5/catalogue.json,
#  'cmip5_gr1p5': name: cmip5_gr1p5
#  container: xarray
#  plugin: ['esm_datastore']
#  driver: ['esm_datastore']
#  description: CMIP5 (Regridded)
#
#  Post-processed CMIP5 files regridded to a common grid.
#
#  Project: lp01
#
#  direct_access: forbid
#  user_parameters: []
#  metadata:
#  args:
#    esmcol_obj: /home/548/pfd548/intake-esm-datastore/catalogs/nci-gr1.5-cmip5.json,
#  'cmip6': name: cmip6
#  container: xarray
#  plugin: ['esm_datastore']
#  driver: ['esm_datastore']
#  description: CMIP6 (Latest Versions)
#
#  Datasets on Gadi, both publised and replicated. Only the latest available file versions are in the listing, see catalogue 'cmip6_all' for all available versions
#
#  Catalogue columns match those used by ESGF search (esgf.nci.org.au). intake-esm dict keys are in the form '{esgf instance_id}'.
#
#  Project: oi10, fs38
#  Maintained By: NCI
#  Contact: help@nci.org.au
#  References:
#      - https://pcmdi.llnl.gov/CMIP6/
#
#  direct_access: forbid
#  user_parameters: []
#  metadata:
#  args:
#    esmcol_obj: {{CATALOG_DIR}}/cmip6/catalogue_latest.json,
#  'cmip6_all': name: cmip6_all
#  container: xarray
#  plugin: ['esm_datastore']
#  driver: ['esm_datastore']
#  description: CMIP6 (All Versions)
#
#  Datasets on Gadi, both publised and replicated. All file versions present are in the listing, see catalogue 'cmip6' for only the latest versions
#
#  Catalogue columns match those used by ESGF search (esgf.nci.org.au). intake-esm dict keys are in the form '{esgf instance_id}'.
#
#  Project: oi10, fs38
#  Maintained By: NCI
#  Contact: help@nci.org.au
#  References:
#      - https://pcmdi.llnl.gov/CMIP6/
#
#  direct_access: forbid
#  user_parameters: []
#  metadata:
#  args:
#    esmcol_obj: {{CATALOG_DIR}}/cmip6/catalogue.json,
#  'cmip6_gr1p5': name: cmip6_gr1p5
#  container: xarray
#  plugin: ['esm_datastore']
#  driver: ['esm_datastore']
#  description: CMIP6 (Regridded)
#
#  Post-processed CMIP6 files regridded to a common grid.
#
#  Project: lp01
#
#  direct_access: forbid
#  user_parameters: []
#  metadata:
#  args:
#    esmcol_obj: /home/548/pfd548/intake-esm-datastore/catalogs/nci-gr1.5-cmip6.json,
#  'cordex': name: cordex
#  container: xarray
#  plugin: ['esm_datastore']
#  driver: ['esm_datastore']
#  description: CORDEX (Latest Versions)
#
#  Datasets on Gadi, both publised and replicated. Only the latest available file versions are in the listing, see catalogue 'cordex_all' for all available versions
#
#  Catalogue columns match those used by ESGF search (esgf.nci.org.au). intake-esm dict keys are in the form '{esgf instance_id}'. Column 'rcm_model_id' mirrors the non-'_id' column, with minor formatting differences needed to create the 'instance_id'.
#
#  Project: al33, rr3
#  Maintained By: NCI
#  Contact: help@nci.org.au
#  References:
#      - https://cordex.org/
#
#  direct_access: forbid
#  user_parameters: []
#  metadata:
#  args:
#    esmcol_obj: {{CATALOG_DIR}}/cordex/catalogue_latest.json,
#  'cordex_all': name: cordex_all
#  container: xarray
#  plugin: ['esm_datastore']
#  driver: ['esm_datastore']
#  description: CORDEX (All Versions)
#
#  Datasets on Gadi, both publised and replicated. All file versions present are in the listing, see catalogue 'cordex' for only the latest versions
#
#  Catalogue columns match those used by ESGF search (esgf.nci.org.au). intake-esm dict keys are in the form '{esgf instance_id}'. Column 'rcm_model_id' mirrors the non-'_id' column, with minor formatting differences needed to create the 'instance_id'.
#
#  Project: al33, rr3
#  Maintained By: NCI
#  Contact: help@nci.org.au
#  References:
#      - https://cordex.org/
#
#  direct_access: forbid
#  user_parameters: []
#  metadata:
#  args:
#    esmcol_obj: {{CATALOG_DIR}}/cordex/catalogue.json}

# %%
# NB cmip6_gr1p5 is cmip6 post-processed data and cmip6_all includes all versions and not just the latest.
# We want `cmip6` original data only and we can look at its records as a pandas dataframe
cmip6 = cat['esgf'].cmip6
cmip6.df.head()
# Out:
#   project activity_id institution_id source_id experiment_id member_id  \
# 0   CMIP6  AerChemMIP            BCC  BCC-ESM1       histSST  r1i1p1f1
# 1   CMIP6  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1
# 2   CMIP6  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1
# 3   CMIP6  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1
# 4   CMIP6  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1
#
#   table_id variable_id grid_label     date_range  \
# 0   AERmon          o3         gn  185001-201412
# 1     Amon     fco2nat         gn  201501-205512
# 2     Amon          pr         gn  201501-205512
# 3     Amon         psl         gn  201501-205512
# 4     Amon        rlut         gn  201501-205512
#
#                                                 path    version
# 0  /g/data/oi10/replicas/CMIP6/AerChemMIP/BCC/BCC...  v20190718
# 1  /g/data/oi10/replicas/CMIP6/AerChemMIP/BCC/BCC...  v20190624
# 2  /g/data/oi10/replicas/CMIP6/AerChemMIP/BCC/BCC...  v20190624
# 3  /g/data/oi10/replicas/CMIP6/AerChemMIP/BCC/BCC...  v20190624
# 4  /g/data/oi10/replicas/CMIP6/AerChemMIP/BCC/BCC...  v20190624

# %%
# `df.columns` lists all the columns that can be used to query the data
cmip6.df.columns
# Out:
# Index(['project', 'activity_id', 'institution_id', 'source_id',
#        'experiment_id', 'member_id', 'table_id', 'variable_id', 'grid_label',
#        'date_range', 'path', 'version'],
#       dtype='object')

# %%
# Other useful attributes of a catalogue:
# - `description` 
# - `aggregation_info` how the data can be aggregated
cmip6.description
cmip6.aggregation_info
# Out:
# AggregationInfo(groupby_attrs=['project', 'activity_id', 'institution_id', 'source_id', 'experiment_id', 'member_id', 'table_id', 'variable_id', 'grid_label', 'version'], variable_column_name='variable_id', aggregations=[{'type': 'join_existing', 'attribute_name': 'date_range', 'options': {'dim': 'time'}}], agg_columns=['date_range'], aggregation_dict={'date_range': {'type': 'join_existing', 'options': {'dim': 'time'}}})

# %%
# The method unique() lists all the unique values for each column as a dictionary
# As this would be quite big for CMIP6, we are going to save it in avariable and access only the valid model names (source_id)
values_dict = cmip6.unique()
values_dict['source_id']
# Out:
# {'count': 100,
#  'values': ['ECMWF-IFS-LR',
#   'IPSL-CM6A-LR',
#   'FGOALS-g3',
#   'BCC-CSM2-HR',
#   'GISS-E2-2-G',
#   'TaiESM1',
#   'EC-Earth3-Veg-LR',
#   'KACE-1-0-G',
#   'MPI-ESM1-2-LR',
#   'IPSL-CM5A2-INCA',
#   'NICAM16-9S',
#   'ACCESS-CM2',
#   'GFDL-ESM2M',
#   'IPSL-CM6A-ATM-HR',
#   'INM-CM5-0',
#   'GFDL-ESM4',
#   'CMCC-CM2-VHR4',
#   'E3SM-1-0',
#   'ICON-ESM-LR',
#   'CESM2',
#   'BCC-ESM1',
#   'MCM-UA-1-0',
#   'MRI-AGCM3-2-S',
#   'GFDL-OM4p5B',
#   'TaiESM1-TIMCOM',
#   'BCC-CSM2-MR',
#   'MIROC6',
#   'CAS-ESM2-0',
#   'HiRAM-SIT-LR',
#   'ACCESS-OM2',
#   'E3SM-1-1',
#   'GFDL-CM4',
#   'CMCC-CM2-SR5',
#   'MIROC-ES2H',
#   'GFDL-AM4',
#   'CAMS-CSM1-0',
#   'SAM0-UNICON',
#   'NICAM16-7S',
#   'CNRM-CM6-1',
#   'GISS-E2-1-G',
#   'ECMWF-IFS-MR',
#   'CanESM5-CanOE',
#   'MPI-ESM1-2-XR',
#   'UKESM1-0-LL',
#   'FGOALS-f3-H',
#   'GISS-E2-1-H',
#   'CNRM-ESM2-1',
#   'FIO-ESM-2-0',
#   'NorESM2-MM',
#   'AWI-ESM-1-1-LR',
#   'NorCPM1',
#   'HadGEM3-GC31-MM',
#   'CESM2-WACCM',
#   'GISS-E2-1-G-CC',
#   'INM-CM5-H',
#   'EC-Earth3-LR',
#   'E3SM-1-1-ECA',
#   'CIESM',
#   'FGOALS-f3-L',
#   'EC-Earth3-CC',
#   'HadGEM3-GC31-HH',
#   'GFDL-CM4C192',
#   'EC-Earth3P',
#   'MPI-ESM1-2-HR',
#   'NESM3',
#   'CMCC-CM2-HR4',
#   'CESM1-1-CAM5-CMIP5',
#   'CNRM-CM6-1-HR',
#   'CanESM5',
#   'UKESM1-1-LL',
#   'MPI-ESM-1-2-HAM',
#   'NorESM1-F',
#   'GISS-E2-2-H',
#   'HadGEM3-GC31-LM',
#   'EC-Earth3-Veg',
#   'HadGEM3-GC31-LL',
#   'CESM2-FV2',
#   'MRI-ESM2-0',
#   'ECMWF-IFS-HR',
#   'CMCC-ESM2',
#   'NICAM16-8S',
#   'MRI-AGCM3-2-H',
#   'EC-Earth3-AerChem',
#   'EC-Earth3P-HR',
#   'NorESM2-LM',
#   'CESM1-CAM5-SE-HR',
#   'TaiESM1-TIMCOM2',
#   'MIROC-ES2L',
#   'HiRAM-SIT-HR',
#   'ACCESS-OM2-025',
#   'HadGEM3-GC31-HM',
#   'CESM1-CAM5-SE-LR',
#   'IITM-ESM',
#   'CESM2-WACCM-FV2',
#   'AWI-CM-1-1-MR',
#   'EC-Earth3',
#   'KIOST-ESM',
#   'ACCESS-ESM1-5',
#   'INM-CM4-8',
#   'IPSL-CM6A-LR-INCA']}

# %%
# Let's select a subset passing the search() method some constraints
subset = cmip6.search(activity_id='CMIP', experiment_id='historical', source_id='ACCESS-CM2', table_id='day', variable_id='tas')
subset
# Out:
# <p><strong>cmip6 catalog with 5 dataset(s) from 20 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>project</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>date_range</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# to_dataset_dict() returns a dictionary listing all the datasets in our subset
dset_dict = subset.to_dataset_dict()
dset_dict
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.activity_id.institution_id.source_id.experiment_id.member_id.table_id.variable_id.grid_label.version'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:03<00:00]
#     </div>
# {'CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r3i1p1f1.day.tas.gn.v20200306': <xarray.Dataset>
#  Dimensions:    (time: 60265, bnds: 2, lat: 144, lon: 192)
#  Coordinates:
#    * time       (time) datetime64[ns] 1850-01-01T12:00:00 ... 2014-12-31T12:00:00
#    * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#      height     float64 2.0
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(18262, 2), meta=np.ndarray>
#      lat_bnds   (lat, bnds) float64 -90.0 -88.75 -88.75 ... 88.75 88.75 90.0
#      lon_bnds   (lon, bnds) float64 0.0 1.875 1.875 3.75 ... 358.1 358.1 360.0
#      tas        (time, lat, lon) float32 dask.array<chunksize=(18262, 144, 192), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:             CF-1.7 CMIP-6.2
#      initialization_index:    1
#      branch_method:           standard
#      further_info_url:        https://furtherinfo.es-doc.org/CMIP6.CSIRO-ARCCS...
#      sub_experiment:          none
#      experiment_id:           historical
#      ...                      ...
#      physics_index:           1
#      table_id:                day
#      table_info:              Creation Date:(30 April 2019) MD5:40e9ef53d4d2ec...
#      notes:                   Exp: CM2-historical; Local ID: bm652; Variable: ...
#      source_type:             AOGCM
#      intake_esm_dataset_key:  CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r3...,
#  'CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r1i1p1f1.day.tas.gn.v20191108': <xarray.Dataset>
#  Dimensions:    (time: 60265, bnds: 2, lat: 144, lon: 192)
#  Coordinates:
#    * time       (time) datetime64[ns] 1850-01-01T12:00:00 ... 2014-12-31T12:00:00
#    * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#      height     float64 2.0
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(18262, 2), meta=np.ndarray>
#      lat_bnds   (lat, bnds) float64 -90.0 -88.75 -88.75 ... 88.75 88.75 90.0
#      lon_bnds   (lon, bnds) float64 0.0 1.875 1.875 3.75 ... 358.1 358.1 360.0
#      tas        (time, lat, lon) float32 dask.array<chunksize=(18262, 144, 192), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:             CF-1.7 CMIP-6.2
#      initialization_index:    1
#      branch_method:           standard
#      further_info_url:        https://furtherinfo.es-doc.org/CMIP6.CSIRO-ARCCS...
#      sub_experiment:          none
#      experiment_id:           historical
#      ...                      ...
#      physics_index:           1
#      table_id:                day
#      table_info:              Creation Date:(30 April 2019) MD5:e14f55f257ccea...
#      notes:                   Exp: CM2-historical; Local ID: bj594; Variable: ...
#      source_type:             AOGCM
#      intake_esm_dataset_key:  CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r1...,
#  'CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r4i1p1f1.day.tas.gn.v20210607': <xarray.Dataset>
#  Dimensions:    (time: 60265, bnds: 2, lat: 144, lon: 192)
#  Coordinates:
#    * time       (time) datetime64[ns] 1850-01-01T12:00:00 ... 2014-12-31T12:00:00
#    * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#      height     float64 2.0
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(18262, 2), meta=np.ndarray>
#      lat_bnds   (lat, bnds) float64 -90.0 -88.75 -88.75 ... 88.75 88.75 90.0
#      lon_bnds   (lon, bnds) float64 0.0 1.875 1.875 3.75 ... 358.1 358.1 360.0
#      tas        (time, lat, lon) float32 dask.array<chunksize=(18262, 144, 192), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:             CF-1.7 CMIP-6.2
#      initialization_index:    1
#      branch_method:           standard
#      further_info_url:        https://furtherinfo.es-doc.org/CMIP6.CSIRO-ARCCS...
#      sub_experiment:          none
#      experiment_id:           historical
#      ...                      ...
#      physics_index:           1
#      table_id:                day
#      table_info:              Creation Date:(30 April 2019) MD5:12ec21eb48eb99...
#      notes:                   Exp: CM2-historical; Local ID: cd659; Variable: ...
#      source_type:             AOGCM
#      intake_esm_dataset_key:  CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r4...,
#  'CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r5i1p1f1.day.tas.gn.v20210607': <xarray.Dataset>
#  Dimensions:    (time: 60265, bnds: 2, lat: 144, lon: 192)
#  Coordinates:
#    * time       (time) datetime64[ns] 1850-01-01T12:00:00 ... 2014-12-31T12:00:00
#    * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#      height     float64 2.0
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(18262, 2), meta=np.ndarray>
#      lat_bnds   (lat, bnds) float64 -90.0 -88.75 -88.75 ... 88.75 88.75 90.0
#      lon_bnds   (lon, bnds) float64 0.0 1.875 1.875 3.75 ... 358.1 358.1 360.0
#      tas        (time, lat, lon) float32 dask.array<chunksize=(18262, 144, 192), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:             CF-1.7 CMIP-6.2
#      initialization_index:    1
#      branch_method:           standard
#      further_info_url:        https://furtherinfo.es-doc.org/CMIP6.CSIRO-ARCCS...
#      sub_experiment:          none
#      experiment_id:           historical
#      ...                      ...
#      physics_index:           1
#      table_id:                day
#      table_info:              Creation Date:(30 April 2019) MD5:12ec21eb48eb99...
#      notes:                   Exp: CM2-historical; Local ID: cd884; Variable: ...
#      source_type:             AOGCM
#      intake_esm_dataset_key:  CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r5...,
#  'CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r2i1p1f1.day.tas.gn.v20191125': <xarray.Dataset>
#  Dimensions:    (time: 60265, bnds: 2, lat: 144, lon: 192)
#  Coordinates:
#    * time       (time) datetime64[ns] 1850-01-01T12:00:00 ... 2014-12-31T12:00:00
#    * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#      height     float64 2.0
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(18262, 2), meta=np.ndarray>
#      lat_bnds   (lat, bnds) float64 -90.0 -88.75 -88.75 ... 88.75 88.75 90.0
#      lon_bnds   (lon, bnds) float64 0.0 1.875 1.875 3.75 ... 358.1 358.1 360.0
#      tas        (time, lat, lon) float32 dask.array<chunksize=(18262, 144, 192), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:             CF-1.7 CMIP-6.2
#      initialization_index:    1
#      branch_method:           standard
#      further_info_url:        https://furtherinfo.es-doc.org/CMIP6.CSIRO-ARCCS...
#      sub_experiment:          none
#      experiment_id:           historical
#      ...                      ...
#      physics_index:           1
#      table_id:                day
#      table_info:              Creation Date:(30 April 2019) MD5:e14f55f257ccea...
#      notes:                   Exp: CM2-historical; Local ID: bl655; Variable: ...
#      source_type:             AOGCM
#      intake_esm_dataset_key:  CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r2...}

# %%
# Finally we can simply load a dataset using its key
ds = dset_dict['CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r5i1p1f1.day.tas.gn.v20210607']
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 60265, bnds: 2, lat: 144, lon: 192)
# Coordinates:
#   * time       (time) datetime64[ns] 1850-01-01T12:00:00 ... 2014-12-31T12:00:00
#   * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#   * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#     height     float64 2.0
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(18262, 2), meta=np.ndarray>
#     lat_bnds   (lat, bnds) float64 -90.0 -88.75 -88.75 ... 88.75 88.75 90.0
#     lon_bnds   (lon, bnds) float64 0.0 1.875 1.875 3.75 ... 358.1 358.1 360.0
#     tas        (time, lat, lon) float32 dask.array<chunksize=(18262, 144, 192), meta=np.ndarray>
# Attributes: (12/48)
#     Conventions:             CF-1.7 CMIP-6.2
#     initialization_index:    1
#     branch_method:           standard
#     further_info_url:        https://furtherinfo.es-doc.org/CMIP6.CSIRO-ARCCS...
#     sub_experiment:          none
#     experiment_id:           historical
#     ...                      ...
#     physics_index:           1
#     table_id:                day
#     table_info:              Creation Date:(30 April 2019) MD5:12ec21eb48eb99...
#     notes:                   Exp: CM2-historical; Local ID: cd884; Variable: ...
#     source_type:             AOGCM
#     intake_esm_dataset_key:  CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r5...
