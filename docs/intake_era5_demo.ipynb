# %%
import intake

# %% [markdown]
# The conda envs have already this catalogue installed so intake knows where to find it

# %%
cat = intake.cat.nci

# %% [markdown]
# Use list to see all datasets available

# %%
list(cat)
# Out:
# ['era5', 'era5_land', 'ecmwf', 'esgf', 'cosima', 'erai']

# %% [markdown]
# Select the era5 dataset, this is basically a Pandas DataFrame so you can use the "df" accessor to explore it

# %%
era5 = cat.era5

# %%
era5.df.head()
# Out:
#   sub_collection          dataset             product_type parameter  year  \
# 0         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
# 1         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
# 2         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
# 3         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
# 4         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
#
#    month  startdate file_variable  \
# 0      1   20000101            cc
# 1      2   20000201            cc
# 2      3   20000301            cc
# 3      4   20000401            cc
# 4      5   20000501            cc
#
#                                                 path
# 0  /g/data/rt52/era5-1/pressure-levels/monthly-av...
# 1  /g/data/rt52/era5-1/pressure-levels/monthly-av...
# 2  /g/data/rt52/era5-1/pressure-levels/monthly-av...
# 3  /g/data/rt52/era5-1/pressure-levels/monthly-av...
# 4  /g/data/rt52/era5-1/pressure-levels/monthly-av...

# %% [markdown]
# Unique shows all the unique values for each available attribute

# %%
print(era5.unique()['sub_collection'])
print(era5.unique()['dataset'])
print(era5.unique()['product_type'])
# Out:
# {'count': 2, 'values': ['era5', 'era5-1']}
# {'count': 2, 'values': ['single-levels', 'pressure-levels']}
# {'count': 4, 'values': ['monthly-averaged-by-day', 'monthly-averaged', 'reanalysis', 'monthly-averaged-by-hour']}

# %% [markdown]
# Search will subset based on the selected attributes.<br>
# NB. I used range to create a list of the years you want!<br>

# %%
sub = era5.search(sub_collection='era5',dataset='single-levels', product_type='reanalysis',
                  parameter='10v', year=[x for x in range(1979,2001)])
sub
# Out:
# <p><strong>era5 catalog with 1 dataset(s) from 264 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>sub_collection</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>dataset</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>product_type</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>parameter</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>year</th>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>month</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>startdate</th>
#       <td>264</td>
#     </tr>
#     <tr>
#       <th>file_variable</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>264</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sub.df.head()
# Out:
#   sub_collection        dataset product_type parameter  year  month  \
# 0           era5  single-levels   reanalysis       10v  1979      1
# 1           era5  single-levels   reanalysis       10v  1979      2
# 2           era5  single-levels   reanalysis       10v  1979      3
# 3           era5  single-levels   reanalysis       10v  1979      4
# 4           era5  single-levels   reanalysis       10v  1979      5
#
#    startdate file_variable                                               path
# 0   19790101           v10  /g/data/rt52/era5/single-levels/reanalysis/10v...
# 1   19790201           v10  /g/data/rt52/era5/single-levels/reanalysis/10v...
# 2   19790301           v10  /g/data/rt52/era5/single-levels/reanalysis/10v...
# 3   19790401           v10  /g/data/rt52/era5/single-levels/reanalysis/10v...
# 4   19790501           v10  /g/data/rt52/era5/single-levels/reanalysis/10v...

# %% [markdown]
# This method aggregate the files and create a dictionary containing the resulting datasets. The aggregation is preset in the catalogue definition, you can disable it by passing aggregate=False to the same method.<br>
# To see the details of how the data is aggregate use <br>
# `era5.aggregation_info`

# %%
ds_dict = sub.to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'sub_collection.dataset.product_type'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
ds_dict.keys()
# Out:
# dict_keys(['era5.single-levels.reanalysis'])

# %% [markdown]
# In this case the result is one dataset so you can simply load it using the key.

# %%
ds = ds_dict['era5.single-levels.reanalysis']
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, time: 192864)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 1979-01-01 ... 2000-12-31T23:00:00
# Data variables:
#     v10        (time, latitude, longitude) float32 dask.array<chunksize=(744, 721, 1440), meta=np.ndarray>
# Attributes:
#     summary:                 ERA5 is the fifth generation ECMWF atmospheric r...
#     Conventions:             CF-1.6
#     intake_esm_varname:      ['v10']
#     license:                 Licence to use Copernicus Products: https://apps...
#     history:                 2020-10-04 20:18:05 UTC+1100 by era5_replication...
#     intake_esm_dataset_key:  era5.single-levels.reanalysis

# %% [markdown]
# Now you can treat this as any other xarray Dataset, for example select a region and a variable

# %%
myregion = ds.sel(latitude=slice(0,-60),longitude=slice(100,180))

# %%
v10 = myregion['v10']
